# %% [markdown]
# # The Massachusetts Institute of Technology (MIT)
#
# **Rayne Krebsbach - RaeJoKae**
#
# The Massachusetts Institute of Technology (MIT) is a private university in Cambridge, Massachusetts. Established in 1861, MIT has since then been at the center of the development of modern technology and science. Since it was founded, MIT has been ranked among the top academic institutions in the world. Below is the logo.

# %%
display(Image(filename="PCDE-Activity-9.1/mit_logo.jpg"))
